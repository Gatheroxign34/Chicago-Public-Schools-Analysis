# %%
import pandas as pd
import numpy as np 

cp_schools = pd.read_csv('Cleaned Data Set/Chicago Public Data_Cleaned for Zipcode Specificity .csv')

cp_schools.head()
# Out:
#    School_ID  Legacy_Unit_ID  Finance_ID                   Short_Name  \
# 0   610357.0          7930.0     46461.0                      SPRY HS
# 1   610334.0          7690.0     46471.0                      RABY HS
# 2   609723.0          1470.0     47041.0                  MARSHALL HS
# 3   610385.0          7630.0     55181.0             MULTICULTURAL HS
# 4   400059.0          1106.0     66092.0  NORTH LAWNDALE - COLLINS HS
#
#                                 Long_Name Primary_Category Is_High_School  \
# 0        Spry Community Links High School               HS           True
# 1                     Al Raby High School               HS           True
# 2  John Marshall Metropolitan High School               HS           True
# 3    Multicultural Academy of Scholarship               HS           True
# 4   North Lawndale College Prep - Collins               HS           True
#
#   Is_Middle_School Is_Elementary_School Is_Pre_School  ...  \
# ...

# %%
southlawndale_hschools = cp_schools[cp_schools["Zip"]== 60623]

# %%
print(southlawndale_hschools.head())
# Out:
#    School_ID  Legacy_Unit_ID  Finance_ID                   Short_Name  \
# 0   610357.0          7930.0     46461.0                      SPRY HS
# 3   610385.0          7630.0     55181.0             MULTICULTURAL HS
# 4   400059.0          1106.0     66092.0  NORTH LAWNDALE - COLLINS HS
# 6   610392.0          4460.0     52011.0            WORLD LANGUAGE HS
# 7   609704.0          1300.0     53091.0                  FARRAGUT HS
#
#                                      Long_Name Primary_Category  \
# 0             Spry Community Links High School               HS
# 3         Multicultural Academy of Scholarship               HS
# 4        North Lawndale College Prep - Collins               HS
# 6           World Language Academy High School               HS
# 7  David G Farragut Career Academy High School               HS
#
#   Is_High_School Is_Middle_School Is_Elementary_School Is_Pre_School  ...  \
# 0           True            False                False         False  ...
# ...

# %%
westgarfield_hschools = cp_schools[cp_schools["Zip"]== 60624]

# %%
print(westgarfield_hschools.head())
# Out:
#     School_ID  Legacy_Unit_ID  Finance_ID      Short_Name  \
# 1    610334.0          7690.0     46471.0         RABY HS
# 2    609723.0          1470.0     47041.0     MARSHALL HS
# 5    610389.0          1830.0     28151.0          ORR HS
# 9    400119.0          9036.0     66641.0   LEGAL PREP HS
# 12   400118.0          9035.0     66575.0  NOBLE - DRW HS
#
#                                  Long_Name Primary_Category Is_High_School  \
# 1                      Al Raby High School               HS           True
# 2   John Marshall Metropolitan High School               HS           True
# 5                  Orr Academy High School               HS           True
# 9               Legal Prep Charter Academy               HS           True
# 12                Noble - DRW College Prep               HS           True
#
#    Is_Middle_School Is_Elementary_School Is_Pre_School  ...  \
# 1             False                False         False  ...
# ...
